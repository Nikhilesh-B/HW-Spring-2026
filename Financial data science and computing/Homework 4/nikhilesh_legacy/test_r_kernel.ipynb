# %%
# Fix plot appearance in dark theme: white background, readable text
options(repr.plot.width = 10, repr.plot.height = 6)
par(bg = "white", col.axis = "black", col.lab = "black", col.main = "black", fg = "black")

# %%
# Quick test: R kernel is working
print(paste("R version:", R.version.string))
print(paste("Platform:", R.version$platform))
cat("\n1 + 1 =", 1 + 1, "\n")
# Out:
# [1] "R version: R version 4.1.1 (2021-08-10)"
# [1] "Platform: aarch64-apple-darwin20"
# 1 + 1 = 2

# %%
# Test a simple plot
par(bg = "white", col.axis = "black", col.lab = "black", col.main = "black", fg = "black")
x <- seq(0, 2 * pi, length.out = 100)
plot(x, sin(x), type = 'l', col = 'blue', lwd = 2,
     main = 'R Kernel Test Plot', xlab = 'x', ylab = 'sin(x)')
# Out:
# Plot with title “R Kernel Test Plot”

# %%
# Test reading one of your data files
h1 <- read.csv('h1.csv')
print(h1)
# Out:
#           h1
# 1 CCAT
# 2 ECAT
# 3 GCAT
# 4 MCAT
#                                                                                            description
# 1 CORPORATE/INDUSTRIAL
# 2 ECONOMICS
# 3 GOVERNMENT/SOCIAL
# 4 MARKETS
