# %% [markdown]
# # Problem 3 — SVM benchmarks (index)
#
# Run experiments **one phase per notebook** (full-tree fits are slow).
#
# | Phase | Notebook | What |
# |-------|----------|------|
# | **1** | [`hierarchical_problem3_phase1_features.ipynb`](hierarchical_problem3_phase1_features.ipynb) | TF-IDF vs TF (L2) vs count |
# | **2** | [`hierarchical_problem3_phase2_truncated_svd.ipynb`](hierarchical_problem3_phase2_truncated_svd.ipynb) | `TfidfVectorizer` → `TruncatedSVD` → `LinearSVC` |
# | **3** | [`hierarchical_problem3_phase3_by_depth.ipynb`](hierarchical_problem3_phase3_by_depth.ipynb) | Slack **`C`** (global grid + optional **`C_by_depth`**) |
# | **4** | [`hierarchical_problem3_phase4_kernel_pilot.ipynb`](hierarchical_problem3_phase4_kernel_pilot.ipynb) | Linear / RBF / poly `SVC` pilot on one edge |
#
# **Old combined notebook:** [`hierarchical_problem3_svm_benchmark.ipynb`](hierarchical_problem3_svm_benchmark.ipynb) now redirects here.
#
# Shared code: [`binary_edge_factory`](hierarchical_classifier.py), [`train_full_tree_and_summarize`](hierarchical_summary_metrics.py), test split `ft_*` + `leaf_*`.
