# %% [markdown]
# # Problem 3 — combined notebook (deprecated)
#
# Experiments are split into **four phase notebooks**. Start here:
#
# → **[`hierarchical_problem3_index.ipynb`](hierarchical_problem3_index.ipynb)**
#
# - [Phase 1 — features](hierarchical_problem3_phase1_features.ipynb)
# - [Phase 2 — TruncatedSVD](hierarchical_problem3_phase2_truncated_svd.ipynb)
# - [Phase 3 — SVM C by depth](hierarchical_problem3_phase3_by_depth.ipynb)
# - [Phase 4 — kernel pilot](hierarchical_problem3_phase4_kernel_pilot.ipynb)
