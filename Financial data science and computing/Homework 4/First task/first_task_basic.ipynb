# %%
import pandas as pd

# %%
news_test = pd.read_csv("../news_test.csv")
news_train = pd.read_csv("../news.csv")

# %%
print(len(news_test))
print(len(news_train))
# Out:
# 390616
# 23149

# %%
topics = pd.read_csv("../news_topics.csv")

# %%
topics
# Out:
#              id  id_cat         cat
# 0          2286      41  E11
# 1          2286      72  ECAT
# 2          2286     108  M11
# 3          2286     109  M12
# 4          2286     117  MCAT
# ...         ...     ...         ...
# 2606870  810935      42  E12
# 2606871  810935      72  ECAT
# 2606872  810935     113  M14
# 2606873  810935     115  M142
# 2606874  810935     117  MCAT
#
# [2606875 rows x 3 columns]

# %%
master_id = set(topics["id"])
train_ids  = set(news_train["id"])
test_ids = set(news_test["id"])

# %%
print(len(train_ids-(train_ids&master_id)))
print(len(test_ids-(test_ids&master_id)))
# Out:
# 0
# 0
